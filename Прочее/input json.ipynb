# %%
import pandas as pd
import xlrd
import numpy as np

# %%
cc='/Users/anna/Downloads/наименования клиентов.xlsx'

rb = xlrd.open_workbook(cc)
sheet = rb.sheet_by_index(0)
a=[]
for rownum in range(sheet.nrows):
    row = sheet.row_values(rownum)
    for c_el in row:
        a.append(c_el)

# %%
code_client=[]
name_client=[]



for i in range(0,len(a),2):
    code_client.append(a[i])
for i in range(1,len(a),2):
    name_client.append(a[i])

# %%
import requests,json
import pandas as pd    

#встречи запланированные и прошедшие

URL_LOG= "https://1s.garagetools.ru/vesna/hs/external_processing/calendar/"
LOGIN="АгаповаА"
PASS="6465667Aa"

s=requests.Session()

data= {"Username": LOGIN   ,
      "Password": PASS}

headers={"accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
         "accept-encoding":"gzip, deflate, br",
         "accept-language":"en-US,en;q=0.9",
         "authorization":"Basic 0JDQs9Cw0L/QvtCy0LDQkDo2NDY1NjY3QWE=",
         "cache-control":"max-age=0",
         "sec-fetch-dest":"document",
         "sec-fetch-mode":"navigate",
         "sec-fetch-site":"none",
         "sec-fetch-user":"?1",
         "upgrade-insecure-requests":"1",
         "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    
}
import io



r1=s.get(URL_LOG, data=data, headers=headers)

data=json.loads(r1.content)
df = pd.json_normalize(data)

# %%
URL_LOG= "https://1s.garagetools.ru/vesna/hs/external_processing/weekday/"

LOGIN="АгаповаА"
PASS="6465667Aa"

s=requests.Session()

data= {"Username": LOGIN   ,
      "Password": PASS}

headers={"accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
         "accept-encoding":"gzip, deflate, br",
         "accept-language":"en-US,en;q=0.9",
         "authorization":"Basic 0JDQs9Cw0L/QvtCy0LDQkDo2NDY1NjY3QWE=",
         "cache-control":"max-age=0",
         "sec-fetch-dest":"document",
         "sec-fetch-mode":"navigate",
         "sec-fetch-site":"none",
         "sec-fetch-user":"?1",
         "upgrade-insecure-requests":"1",
         "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    
}
import io



r1=s.get(URL_LOG, data=data, headers=headers)

days=json.loads(r1.content)
df_day = pd.json_normalize(data)

# %%
URL_LOG= "https://1s.garagetools.ru/vesna/hs/external_processing/customers/000000009"
LOGIN="АгаповаА"
PASS="6465667Aa"

s=requests.Session()

data= {"Username": LOGIN   ,
      "Password": PASS}

headers={"accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
         "accept-encoding":"gzip, deflate, br",
         "accept-language":"en-US,en;q=0.9",
         "authorization":"Basic 0JDQs9Cw0L/QvtCy0LDQkDo2NDY1NjY3QWE=",
         "cache-control":"max-age=0",
         "sec-fetch-dest":"document",
         "sec-fetch-mode":"navigate",
         "sec-fetch-site":"none",
         "sec-fetch-user":"?1",
         "upgrade-insecure-requests":"1",
         "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    
}
import io



r1=s.get(URL_LOG, data=data, headers=headers)

data2=json.loads(r1.content)
df2 = pd.json_normalize(data2)

# %%
codes=[]
names=[]
address=[]
wh_add=[]

for i in range(len(df2)):
    a=pd.json_normalize(df2['address'][i])
    codes.append(df2.iloc[i][0])
    names.append(df2.iloc[i][1])
    ab=0
    if str(a).find('Фактический')>=0:
        for j in range(len(a)):
            if str(a.iloc[j][0]).find('Фактический')>=0 and ab==0:
                address.append(a.iloc[j][1])
                wh_add.append('Факт')
                ab=5
                
    else: 
        address.append(a.iloc[0][1])
        wh_add.append('Юр')

# %%
addresses=[]
for j in range(len(code_client)):
    address_client=''
    for m in range(len(codes)):
        if codes[m]==code_client[j]:
            address_client=address[m]
    addresses.append(address_client)
table_fin = pd.DataFrame(list(zip(code_client,name_client,addresses)))

# %%
df.to_excel('12mm2m.xlsx')

# %%
result=df.to_json(orient="table")
parsed = json.loads(result)
data_ks=json.dumps(parsed, indent=4).encode('utf-8').decode('unicode-escape')

# %%
lll=pd.json_normalize(parsed)

# %%
iii=lll.iloc[0][0]

# %%
pd.json_normalize(iii)
# Out:
#      index                 date                          owner  \
# 0        0  2020-10-13T13:00:00  Курилко Алексей Александрович
# 1        1  2020-10-08T13:00:00  Курилко Алексей Александрович
# 2        2  2020-10-08T14:00:00  Курилко Алексей Александрович
# 3        3  2020-10-09T15:00:00  Курилко Алексей Александрович
# 4        4  2020-10-01T12:00:00  Курилко Алексей Александрович
# ..     ...                  ...                            ...
# 650    650  2020-10-06T14:00:00       Буравлев Никита Игоревич
# 651    651  2020-10-06T12:00:00       Буравлев Никита Игоревич
# 652    652  2020-10-07T12:00:00       Буравлев Никита Игоревич
# 653    653  2020-10-20T15:00:00       Буравлев Никита Игоревич
# 654    654  2020-10-22T15:00:00       Буравлев Никита Игоревич
#
#          department   customer          state
# 0     ОПП Хабаровск  У00006840  Запланировано
# 1     ОПП Хабаровск  У00078902  Запланировано
# 2     ОПП Хабаровск  У00031860  Запланировано
# ...
